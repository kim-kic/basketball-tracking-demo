# %%
from ultralytics import YOLO

# モデルの読み込み（物体検知モデル）
model = YOLO('yolov8n.pt')  # Load an official Detect model

#source='../videos/istockphoto-1502948311-640_adpp_is.mp4'
source='https://www.youtube.com/watch?v=RZsCJZVLwmg'

results = model.track(source=source, show=True, device='mps')
# Out:
# 1/1: https://www.youtube.com/watch?v=RZsCJZVLwmg... Success ✅ (17611 frames of shape 1920x1080 at 29.97 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 3 persons, 16.2ms
# 0: 384x640 3 persons, 15.2ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# 0: 384x640 3 persons, 17.8ms
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# WARNING ⚠️ Waiting for stream 0
# ...
